# %%
from lesslines.phys.piecewise import PiecewiseMotion

print(PiecewiseMotion)
# Out:
# <class 'lesslines.phys.piecewise.PiecewiseMotion'>

# %%
to = 0
vo = 10
xo = 0
tin = [5, 5, 0]
acc = [-2, 2, 0]

motion = PiecewiseMotion(to, vo, xo, tin, acc)
motion.plot(resolution=1000)

# %%
to = 0
vo = 10
xo = 0
tin = [5, 5, 0]
acc = [-2, 2, 0]

motion = PiecewiseMotion(to, vo, xo, tin, acc)
motion.plot(resolution=10)
